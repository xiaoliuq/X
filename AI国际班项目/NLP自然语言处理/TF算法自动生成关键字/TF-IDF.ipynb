# %%
import pkuseg
from sklearn import feature_extraction
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
seg=pkuseg.pkuseg()
filenames=["txt1.txt","txt2.txt","txt3.txt"]

def is_chinese(uchar):
    if uchar>=u'\u4e00' and uchar <=u'\u9fa5':
        return True;
    else:
        return False;

# %%
def format_str(content):
    content_str=''
    for i in content:
        if is_chinese(i):
            content_str=content_str+i
    return content_str

# %%
if __name__=="__main__":
    corpus=[]
    for name in filenames:
        with open(name,'r',encoding='utf-8') as f:
            str=f.read();
            str=format_str(str)
            str=seg.cut(str)
            corpus.append(" ".join(str))
    print(corpus)
# Out:
# ['四十 年前 法国 陆军 采用 了 一 款 国产 新型 突击 步枪 使 该国 的 步兵 的 制式 小型 武器 技术 一下子 跃升 至 最 先进 的 存在 这 款 步枪 是 设计 由 生产 的 新型 小口径 无托 突击 步枪 突击 步枪 是 一 款 完全 现代化 的 武器 取代 了 当时 法国 军队 中 服役 的 老旧 的 步枪 和 冲锋枪 紧凑 而 紧凑 非常 适合 法国 在 欧洲 和 其他 法国 的 殖民地 环境 中 的 使用 在 年代 法国 陆军 老旧 步枪 就 已经 开始 落后 当时 大部分 法国 军队 都 装备 了 战斗 步枪 是 一 款 气动式 的 半自动 步枪 装备 发 容量 弹匣 的 毫米 步枪 枪弹 这 款 轻型 步枪 重磅 能 发射 步枪 榴弹 武器 本来 是 第二 次 世界 大战 的 好 武器 但 到 了 年代 它 被 彻底 击败 了 既 轻巧 又 比 法国 步枪 使用 容量 更 大 的 弹匣 就 原始 火力 而 言名 法国 士兵 同时 打完 一个 弹匣 也 就是 发 子弹 但是 配备 有的 前 苏联 军队 的 名 士兵 在 同一 时间 则 可以 发射 发 子弹 火力 投射 方面 完胜 因此 法国 陆军 于 年代 开始 寻找 新型 步枪 尽管 它 可以 很 容易 地 购买 到 诸如 德国 之类 的 经过 验证 的 毫米 自动 步枪 但 让 当时 的 法国 高卢主义者 会 采用 外国 武器 那 是 不 存在 的 最终 法国 陆军 军官 和 小武器 设计师 保罗泰利 致力 研制 出 一 种 可以 替代 和 冲锋枪 的 武器 到 年 他 拥有 了 可 使用 的 原型枪 并且 从年 至年 对 该 武器 进行 了 实地 试验年 法国 陆军 正式 采用 了 泰利 的 新型 步枪 也 就是 该 枪 的 字母 缩写 意思 为由 圣艾蒂安 生产 的 轻型 自动 步枪 是 世界 上 最 早 的 无托式 突击 步枪 之一 这种 武器 通过 将 全枪 机构 和 弹匣 都 放置 在 扳机 后面 从而 缩短 了 全枪 长度 这 允许 武器 具有 较 长 的 枪管 同时 又 保持 相对 紧凑 的 外形 的 枪管长 为 英寸 总长度 为 英寸 相比之下 美国 卡宾枪 的 枪管长 为 英寸 但 总 长度 却 为 英寸 与 许多 现代 步兵 武器 的 内部 主要 基于 和 系列 武器 不同 使用 不 寻常 的 杠杆 延迟 反冲 系统 的 原始 步枪 使用 专用 的 发弹 匣 而 下一代 于 年代 问世 后 就 使用 北约 标准 的 发弹 匣 可 使用 较 老 的 弹药 以及 较 新 的 北约 穿甲 弹药 主要 限于 法国 海军 和 海军 突击队 而 法国 陆军 则 继续 使用 的 突击 步枪 射速 相对 较 高 每 分钟 发射 发 至发 该 步枪 具有 单发 三 发 连发 和 全自动 射击 能力 可以 通过 从 枪口 发射 步枪 榴弹 来 增强 法国 步兵 的 火力 尽管 该 武器 的 长度 很 短但 它 仍然 标配 了 战斗 刺刀 这是 一 种 武器 特有 的 配件 也 会 加长 步枪 的 长度 参与 了 许多 冲突 包括 年 的 沙漠 风暴 行动 北约 对 阿富汗 的 干预 以及 在 法国 殖民 非洲 乃至 法国 本身 的 众多 安全 部署 在 年代 初期 法国 陆军 的 未来 步兵 士兵 系统 与 步枪 结合 配备 了 影像 增强 瞄准器 和 士兵 佩戴 的 电子 单片 眼镜 成为 一 种 可以 完全 从 掩体 内 不 暴露 射手 就 能 发射 的 制式 武器 法军 士兵 使用 新型 步枪 瞄准器 可以 瞄准 自己 视线 之外 的 目标 法国 军队 购买 了 套 系统 不过 在 年即 服役 近 四十 年后 步枪 依然 被 新式 的 突击 步枪 所 取代 在年 至 年 之间 德国 武器 承包商 向 法国 陆军 提供 枝 突击 步枪 以 取代 法军 前线 作战 部队 中 使用 的 法国 陆军 的 总 兵力 约 为 万 这 意味着 某些 单位 可能 会 在 年代 后期 甚至 更 长 时间 内 还要 继续 使用 步枪', '据 印度 媒体 月日 最新 报道 印度 军方 表示 当地 时间 周三 夜间 印度 战略 导弹 部队 成功 试射 了 两 枚 大地 近程 核 弹道 导弹 这 也 是 继 不久前 印度 连续 试射 潜射 导弹 烈火 中程 弹道 导弹 之后 该国 又 一 次 发射 核 导弹 而 值得 注意 的 是 就 在 印度 试射 核 导弹 之前 几 天 巴基斯坦 刚 发射 了 射程 近 千 公里 的 沙欣 中程 弹道 导弹 印度 此举 除了 对 巴基斯坦 发出 警告 之外 还是 对 巴铁 的 盟友 发出 信号 谁 敢 插手 帮 巴基斯坦 的话 就 在 印度 核 导弹 的 射程 之内 以 印度 目前 装备 的 核 导弹 来看 只 需要 分钟 就 能 从 本土 命中 周边 邻国 理论 上 确实 具备 一定 的 核 威慑 能力 但是 专家 表示 印度 核 导弹 技术 水平 落后 于 世界 潮流 最 大 弱点 就是 准备 时间 长 速度 较 慢 较 容易 被 现代化 反导 系统 拦截 据 报道 印度 军方 代表 指出 此次 发射 任务 是 由 位于 印度 专用 导弹 基地 的 移动 载具 上 发射 所有 两 次 导弹 试射 都 取得 了 圆满 成功 测试 的 参数 也 符合 预期 据悉 大地 是 印度 军方 仅 有的 战术 核 导弹 之一 射程 大约 为 公里 可 携带 吨重 的 核弹头 虽然 印度 军方 表示 此次 试射 完全 是 例行 训练 旨在 检验 印度 核力量 的 可靠性 和 有效性 但是 外界 普遍 认为 这是 新德里 在 对 巴基斯坦 及其 盟友 进行 警告 但是 虽然 印度 不断 展示 核 肌肉 但是 外界 普遍 认为 印度 的 核武库 最多 只能 和 巴基斯坦 达到 平衡 甚至 还 略 处于 下风 和 巴基斯坦 的 全天候 盟友 相比 则 相差 甚 远 除了 核弹头 数量 较 少 之外 印度 在 核弹头 小型化 等 关键 技术 上都 值得 怀疑 而且 印度 的 核 导弹 部队 战备 能力 也 不容乐观 之前 曾 多次 试射 导弹 失败 被 戏称 为 布朗 运动 导弹 而且 原因 五花八门 这 对于 一个 有 核 国家 来说 并 不是 一 件 值得 骄傲 的 成就 军事 专家 认为 巴基斯坦 的 核 威慑 十分 有 针对性 就是 用于 威慑 假想敌 印度 因此 该国 在 研制 了 射程 超过 公里 的 中程 弹道 导弹 之后 就 已经 满足 作战 需求 足够 覆盖 印度 全境 但是 印度 的 核力量 却 更 具 野心 不但 要 应对 巴基斯坦 的 核 威慑 还 希望 对 其他 周边 大国 构成 可信 的 核威胁 但是 由于 印度 始终 没有 掌握 洲际 导弹 和 相关 的 移动 发射 技术 因此 其 核 部队 实际上 非常 脆弱 战时 很 容易 被 其他 国家 先发制人 打击 提前 消除 核威胁 因此 印度 近期 频繁 试射 核 导弹 其实 对于 其 真正 想 要 威慑 的 对象 来说 并 没有 什么 太 大 的 威胁', '当地 时间 月日 法国 黄 背心 运动 已经 持续 了 年 之 久 为了 庆祝 黄 背心 运动 的 一 周年 纪念日 大量 巴黎 南特 和 里昂 等 多 个 城市 的 示威者 也 走 上 了 街头 据费 加罗 报 报道 有些 示威者 在 巴黎 的 意大利 广场 莱阿勒 购物 中心 等 地区 对 商店 银行 酒店 等 公共 设施 进行 了 破坏 当地 的 防暴 警察 对 这些 人 进行 了 驱散 并 与 之 发生 了 冲突 仅 一 天 时间 巴黎 警方 就 逮捕 了 名 暴力 示威者 多 个 地铁站 被迫 关闭 法国 的 黄背心 运动 是 一起 年月日 开始 的 抗议 运动 示威者 起初 因为 不满 法国 油价 持续 上涨 以及 马克龙 政府 调高 燃油税 而 上街 抗议 后续 有 更 多 的 人 因为 不满 工资 过 低 生活 成本 过 高 而 加入 示威 的 队伍 最终 这 场 抗议 运动 蔓延 至 全球 多 个 国家 及 地区 该 运动 也 成为 了 法国 自年 的 五月 风暴 运动 以来 最 大规模 的 社会 动荡 其实 自从 去年 月日 以来 大批 身穿 黄色 马甲 背心 的 示威者 就 开始 走 上 了 街头 在 这 一 年 的 时间 里 每个 周六 黄 背心 运动 的 示威者 都会 在 法国 各 大 城市 举行 抗议 示威 活动 通过 游行 袭警 打砸 放火 阻塞 交通 破坏 公共 设施 的 行为 来 引起 政府 的 重视 法国 政府 自然 不 会 容忍 这种 事情 的 发生 自从 黄背心 运动 爆发 后 法国 各地 已经 出动 了 万 名 治安 和 防暴 警察 以及 法国 宪兵 机动队 来 应对 暴力 示威 活动 我们 在 法国 街头 见到 的 蓝色 防暴 车辆 就是 法国 宪兵 机动队 的 装甲车 据 法国 世界报 报道 截至 年月日 在 这 场 持续 了 一 年 的 示威 活动 中 法国 警方 总共 逮捕 了 超过 名黄 背心 运动 的 示威者 而 这 中间 有 多 人 被 法官 做出 了 有罪 判决 同样 的 法国 也 在 年月 通过 了 反暴力 游行法 全面 禁止 蒙面 游行 法案 规定 在 示威 游行 中 故意 遮挡 面部 企图 在 破坏 公共 秩序 后 不 被 认出 的 行为 将 面临 最 高 年 监禁 和 ...

# %%
vectorizer=CountVectorizer()
transformer=TfidfTransformer()
tfidf=transformer.fit_transform(vectorizer.fit_transform(corpus))
word=vectorizer.get_feature_names()
weight=tfidf.toarray()

# %%
for (name,w) in zip(filenames,weight):
    print(name,":")
    loc=np.argsort(-w)
    for i in range(5):
        print(i+1,word[loc[i]],w[loc[i]])
# Out:
# txt1.txt :
# 1 步枪 0.6119037660897885
# 2 法国 0.3490264396561353
# 3 武器 0.32780558897667234
# 4 使用 0.2403907652495597
# 5 陆军 0.19668335338600343
# txt2.txt :
# 1 印度 0.6109597936286153
# 2 导弹 0.5047059164758126
# 3 巴基斯坦 0.21250775430560534
# 4 试射 0.18594428501740468
# 5 威慑 0.13281734644100335
# txt3.txt :
# 1 法国 0.40978434589661283
# 2 运动 0.27318956393107524
# 3 示威者 0.26940858490457587
# 4 示威 0.20954001048133677
# 5 抗议 0.20954001048133677
